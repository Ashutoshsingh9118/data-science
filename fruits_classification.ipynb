# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.read_excel('/content/f.xlsx')
df
# Out:
#     weight(g)  color(0-10)    Size fruis type
# 0         150            7   large      apple
# 1         130            6  meduim      apple
# 2         180            8   large      apple
# 3         100            5   small      apple
# 4         120            3   small     banana
# 5         110            4  meduim     banana
# 6         115            3  meduim     banana
# 7         105            2   small     banana
# 8         160            9   large     orange
# 9         150            8  meduim     orange
# 10        155            9   large     orange
# 11        140            7  meduim     orange

# %%
x=df[['weight(g)','color(0-10)','Size']].values
y=df['fruis type'].values
print(x)
print(y)
# Out:
# [[150 7 'large']
#  [130 6 'meduim']
#  [180 8 'large']
#  [100 5 'small']
#  [120 3 'small']
#  [110 4 'meduim']
#  [115 3 'meduim']
#  [105 2 'small']
#  [160 9 'large']
#  [150 8 'meduim']
#  [155 9 'large']
#  [140 7 'meduim']]
# ['apple' 'apple' 'apple' 'apple' 'banana' 'banana' 'banana' 'banana'
#  'orange' 'orange' 'orange' 'orange']

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
df['size']=label_encoder.fit_transform(df['Size'])
df
# Out:
#     weight(g)  color(0-10)    Size fruis type  size
# 0         150            7   large      apple     0
# 1         130            6  meduim      apple     1
# 2         180            8   large      apple     0
# 3         100            5   small      apple     2
# 4         120            3   small     banana     2
# 5         110            4  meduim     banana     1
# 6         115            3  meduim     banana     1
# 7         105            2   small     banana     2
# 8         160            9   large     orange     0
# 9         150            8  meduim     orange     1
# 10        155            9   large     orange     0
# 11        140            7  meduim     orange     1

# %%
x=df[['weight(g)','color(0-10)','size']]
y=df['fruis type']
print(x)
print(y)
# Out:
#     weight(g)  color(0-10)  size
# 0         150            7     0
# 1         130            6     1
# 2         180            8     0
# 3         100            5     2
# 4         120            3     2
# 5         110            4     1
# 6         115            3     1
# 7         105            2     2
# 8         160            9     0
# 9         150            8     1
# 10        155            9     0
# 11        140            7     1
# 0      apple
# 1      apple
# 2      apple
# 3      apple
# 4     banana
# 5     banana
# 6     banana
# 7     banana
# 8     orange
# 9     orange
# 10    orange
# 11    orange
# Name: fruis type, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
new=np.array([[140,7,1]])
y_pred=knn.predict(new)
print(y_pred)
# Out:
# ['apple']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
